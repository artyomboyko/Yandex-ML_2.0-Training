# %% [markdown]
# # Информативные векторные представления в машинном обучении

# %% [markdown]
# ## План лекции

# %% [markdown]
# 1. Правдоподобие
#
# 2. Векторное представление текста
# 2.1 Bag of Words
# 2.2 TF-IDF
#
# 3. Информативный векторные представления - эммбеддинги.
# 3.1 One-Hot encoding
# 3.2 SVD разложение.
# 3.3. Word2Ver (n-грамма, skip-грамма)
# def. Логит - ненормированная вероятность.
# 3.3.1 Word2Vec Subsempling
# 3.3.2 Word2Vec negative sampling
#
#
# 4.
#
# 5.
