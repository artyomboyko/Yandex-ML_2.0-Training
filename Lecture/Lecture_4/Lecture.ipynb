# %% [markdown]
# # Лекция 4: Машинный перевод

# %% [markdown]
# ### Word-based SMT: Noisy channel

# %% [markdown]
# ### PBMT (Phrase-Based Machine Translation)

# %% [markdown]
# ### Нейросетевой перевод

# %% [markdown]
# #### Токенизация Byte-Pair Encoding

# %% [markdown]
# #### Sequence to sequence models

# %% [markdown]
# #### Encoder-Decoder модель

# %% [markdown]
# #### Attention

# %% [markdown]
# #### Обучение

# %% [markdown]
# ##### Mini-batch SGD

# %% [markdown]
# ##### Length-based padding

# %% [markdown]
# #### Оценка качества перевода

# %% [markdown]
# ##### Потокенные overlap-based метрики

# %% [markdown]
# ##### Нейросетевые автометрики

# %% [markdown]
# ##### Human evaluation (Оценка человека)

# %% [markdown]
# ##### Pointwise метрики

# %% [markdown]
# ##### Метрика выделения ошибок

# %% [markdown]
# ## Машинный перевод в 2024 году

# %% [markdown]
# ### Sparse Fine-tuning
