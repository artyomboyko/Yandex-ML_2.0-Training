# %% [markdown]
# ## Подготовка среды

# %% [markdown]
# ### Импорт библиотек

# %%
from datasets import load_dataset, Features, Value, concatenate_datasets, Dataset, DatasetDict, Audio, ClassLabel
from huggingface_hub import notebook_login
import pandas as pd 
import numpy as np

# %% [markdown]
# ## Загрука данных

# %% [markdown]
# Загрузим датасет:

# %%
train_df = pd.read_csv('./ml_trains_data/train.tsv', sep = '\t', encoding='utf-8')
test_df = pd.read_csv('./ml_trains_data/eval.tsv', sep = '\t', encoding='utf-8')

# %%
train_df.rename(columns={'YTID': 'file'}, inplace=True)

train_df['file'] = 'ml_trains_data/clips/' + train_df['file'] + '.flac'
train_df.to_csv('./ml_trains_data/clips/train_metadata.csv', sep = ',', index = False)

test_df.rename(columns={'YTID': 'file'}, inplace=True)
test_df['label'] = None
test_df['file'] = 'ml_trains_data/clips/' + test_df['file'] + '.flac'
test_df.to_csv('./ml_trains_data/clips/test_metadata.csv', sep = ',', index = False)

# %%
train_df['label'].unique()
# Out:
# array(['Music', 'Water', 'Child speech, kid speaking', 'Engine',
#        'Female singing', 'Silence', 'Laughter',
#        'Outside, urban or manmade', 'Singing',
#        'Heavy engine (low frequency)', 'Outside, rural or natural',
#        'Mantra', 'Car passing by', 'Inside, large room or hall',
#        'Fireworks', 'Siren', 'Speech', 'Vehicle', 'Animal',
#        'Whack, thwack', 'Tools', 'Gunshot, gunfire', 'Sound effect',
#        'Whistling', 'Inside, small room', 'Vacuum cleaner', 'Snoring',
#        'Crowd', 'Printer', 'Bird'], dtype=object)

# %%
hw5 = DatasetDict()

labels = ['Music', 'Water', 'Child speech, kid speaking', 'Engine',
       'Female singing', 'Silence', 'Laughter',
       'Outside, urban or manmade', 'Singing',
       'Heavy engine (low frequency)', 'Outside, rural or natural',
       'Mantra', 'Car passing by', 'Inside, large room or hall',
       'Fireworks', 'Siren', 'Speech', 'Vehicle', 'Animal',
       'Whack, thwack', 'Tools', 'Gunshot, gunfire', 'Sound effect',
       'Whistling', 'Inside, small room', 'Vacuum cleaner', 'Snoring',
       'Crowd', 'Printer', 'Bird']

hw5_features = Features({'file': Value('string'), 'label': ClassLabel(names=labels)})

hw5_train = load_dataset("csv", data_files={"train": "./ml_trains_data/clips/train_metadata.csv"}, features=hw5_features).cast_column("file", Audio())

hw5_test = load_dataset("csv", data_files={"test": "./ml_trains_data/clips/test_metadata.csv"}, features=hw5_features).cast_column("file", Audio())

hw5_test['test'][0]
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]

# %% [markdown]
# # Делаем как в домашке с HF

# %%
hw5 = DatasetDict()

labels = ['Music', 'Water', 'Child speech, kid speaking', 'Engine',
       'Female singing', 'Silence', 'Laughter',
       'Outside, urban or manmade', 'Singing',
       'Heavy engine (low frequency)', 'Outside, rural or natural',
       'Mantra', 'Car passing by', 'Inside, large room or hall',
       'Fireworks', 'Siren', 'Speech', 'Vehicle', 'Animal',
       'Whack, thwack', 'Tools', 'Gunshot, gunfire', 'Sound effect',
       'Whistling', 'Inside, small room', 'Vacuum cleaner', 'Snoring',
       'Crowd', 'Printer', 'Bird']

hw5_features = Features({'file': Value('string'), 'label': ClassLabel(names=labels)})

hw5 = load_dataset("csv", data_files={"train": "./ml_trains_data/clips/train_metadata.csv", "test": "./ml_trains_data/clips/test_metadata.csv"}, features=hw5_features).cast_column("file", Audio())

hw5 = hw5.rename_column('file', 'audio')
hw5 = hw5.rename_column('label', 'genre')

hw5['test'].features
# Out:
# {'audio': Audio(sampling_rate=None, mono=True, decode=True, id=None),
#  'genre': ClassLabel(names=['Music', 'Water', 'Child speech, kid speaking', 'Engine', 'Female singing', 'Silence', 'Laughter', 'Outside, urban or manmade', 'Singing', 'Heavy engine (low frequency)', 'Outside, rural or natural', 'Mantra', 'Car passing by', 'Inside, large room or hall', 'Fireworks', 'Siren', 'Speech', 'Vehicle', 'Animal', 'Whack, thwack', 'Tools', 'Gunshot, gunfire', 'Sound effect', 'Whistling', 'Inside, small room', 'Vacuum cleaner', 'Snoring', 'Crowd', 'Printer', 'Bird'], id=None)}

# %%
hw5['train'][1]
# Out:
# {'audio': {'path': 'ml_trains_data/clips/G3y5z37XW8E_200000.flac',
#   'array': array([0.01731741, 0.01920724, 0.02167749, ..., 0.        , 0.        ,
#          0.        ]),
#   'sampling_rate': 16000},
#  'genre': 1}

# %%
notebook_login() # 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

# %%
hw5.push_to_hub(repo_id="hw5", private=True)
# Out:
# ...
# Creating parquet from Arrow format:   0%|          | 0/10 [00:00<?, ?ba/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/artyomboyko/hw5/commit/1232d1273aad66ec9b83e5fca381bf5bf8bf5342', commit_message='Upload dataset', commit_description='', oid='1232d1273aad66ec9b83e5fca381bf5bf8bf5342', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/artyomboyko/hw5', endpoint='https://huggingface.co', repo_type='dataset', repo_id='artyomboyko/hw5'), pr_revision=None, pr_num=None)
